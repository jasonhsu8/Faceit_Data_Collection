# %%
from email.header import Header
from http.client import REQUEST_HEADER_FIELDS_TOO_LARGE
from urllib import request
from dotenv import load_dotenv
import os
import requests
import json
load_dotenv()

faceit_id = os.getenv("FACEIT_PLAYER_ID")
api_key = os.getenv("API_KEY")

print(faceit_id, api_key)
# Out:
# 9a3bf080-a281-4e45-b1c8-2a90c7423d25 a0115c4f-a071-422b-83b8-44fa2fc1cba2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

dfs = []
with open ("Test2(done).json") as file:
    json_data = json.load(file)["items"]

dfs.append(pd.DataFrame([json_data]))
df = pd.concat(dfs, ignore_index=True, sort=False)
df.to_csv('faceit_jj_data.csv') 

print(df)
#df = pd.read_json(json_data, lines=True)
#print(df.to_string())
# Out:
#                                                   0   \
# 0  {'stats': {'Team': 'Poundland', 'Match Id': '1...
#
#                                                   1   \
# 0  {'stats': {'Game Mode': '5v5', 'Created At': '...
#
#                                                   2   \
# 0  {'stats': {'K/R Ratio': '0.59', 'Overtime scor...
#
#                                                   3   \
# 0  {'stats': {'K/R Ratio': '0.57', 'Winner': '9e9...
#
#                                                   4   \
# 0  {'stats': {'First Half Score': '11', 'Created ...
#
#                                                   5   \
# 0  {'stats': {'Second Half Score': '0', 'Map': 'd...
#
#                                                   6   \
# 0  {'stats': {'Nickname': '-JJ-', 'Rounds': '28',...
#
#                                                   7   \
# 0  {'stats': {'Map': 'de_inferno', 'Assists': '4'...
#
#                                                   8   \
# 0  {'stats': {'Game Mode': '5v5', 'Final Score': ...
#
#                                                   9   ...  \
# 0  {'stats': {'Match Round': '1', 'Headshots': '1...  ...
#
#                                                   90  \
# 0  {'stats': {'Match Id': '1-19ce3cc5-a2b0-4c58-b...
#
#                                                   91  \
# 0  {'stats': {'Match Id': '1-7e2f7871-6a6d-4bb7-a...
#
#                                                   92  \
# 0  {'stats': {'Match Id': '1-baca851b-122d-46ed-9...
#
#                                                   93  \
# 0  {'stats': {'Game': 'csgo', 'Triple Kills': '0'...
#
#                                                   94  \
# 0  {'stats': {'Quadro Kills': '1', 'K/R Ratio': '...
#
#                                                   95  \
# 0  {'stats': {'Quadro Kills': '0', 'Created At': ...
#
#                                                   96  \
# 0  {'stats': {'Overtime score': '4', 'Game': 'csg...
#
#                                                   97  \
# 0  {'stats': {'MVPs': '2', 'Player Id': '9a3bf080...
#
#                                                   98  \
# 0  {'stats': {'Map': 'de_mirage', 'Winner': '6329...
#
#                                                   99
# 0  {'stats': {'Headshots %': '41', 'Rounds': '28'...
#
# [1 rows x 100 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

with open ("Test2(done).json") as file1:
    json_data = json.load(file1)

results = json_data

print (results)

#df = pd.read_json(json_data, lines=True)
#print(df)
# Out:
'Game': 'csgo', 'Quadro Kills': '0', 'Penta Kills': '0', 'Deaths': '21', 'Team': 'Poundland', 'First Half Score': '9', 'Player Id': '9a3bf080-a281-4e45-b1c8-2a90c7423d25', 'Headshots %': '62', 'Final Score': '16', 'Rounds': '28', 'Nickname': '-JJ-', 'Triple Kills': '2', 'Kills': '16', 'K/D Ratio': '0.76', 'Best Of': '2', 'Score': '16 / 12', 'Second Half Score': '7', 'Created At': '2023-09-18T19:28:20.413Z', 'Updated At': '2023-09-18T19:28:20.413Z', 'Region': 'EU', 'Game Mode': '5v5', 'Assists': '7'}}, {'stats': {'First Half Score': '11', 'Created At': '2023-09-17T20:55:33.525Z', 'Second Half Score': '5', 'Best Of': '2', 'Match Round': '1', 'Game Mode': '5v5', 'Triple Kills': '1', 'Player Id': '9a3bf080-a281-4e45-b1c8-2a90c7423d25', 'K/R Ratio': '0.92', 'Final Score': '16', 'K/D Ratio': '1.69', 'Result': '1', 'MVPs': '5', 'Updated At': '2023-09-17T20:55:33.525Z', 'Region': 'EU', 'Quadro Kills': '0', 'Winner': '9e913b79-e204-4285-90cb-6a9fbdca32f3', 'Team': 'Poundland', 'Deaths': '13', 'Overtime score': '0', 'Map': 'de_inferno', 'Nickname': '-JJ-', 'Assists': '2', 'Penta Kills': '0', 'Game': 'csgo', 'Rounds': '24', 'Score': '16 / 8', 'Headshots': '11', 'Competition Id': 'e056975c-09ff-4290-8fcd-596cd7295152', 'Headshots %': '50', 'Match Id' ...

# %%
with open("./Test3.json", 'w') as file3:
    json.dump(obj3.json(), file3, indent=2)

with open("./Test4.json", 'w') as file4:
    json.dump(obj4.json(), file4, indent=2)

with open("./Test5.json", 'w') as file5:
    json.dump(obj5.json(), file5, indent=2)

with open("./Test6.json", 'w') as file6:
    json.dump(obj6.json(), file6, indent=2)

with open("./Test7.json", 'w') as file7:
    json.dump(obj7.json(), file7, indent=2)
   
with open("./Test8.json", 'w') as file8:
    json.dump(obj8.json(), file8, indent=2)
   
with open("./Test9.json", 'w') as file9:
    json.dump(obj9.json(), file9, indent=2)

with open("./Test10.json", 'w') as file10:
    json.dump(obj10.json(), file10, indent=2)

with open("./Test11.json", 'w') as file11:
    json.dump(obj11.json(), file11, indent=2)

with open("./Test12.json", 'w') as file12:
    json.dump(obj12.json(), file12, indent=2)

with open("./Test13.json", 'w') as file13:
    json.dump(obj13.json(), file13, indent=2)

with open("./Test14.json", 'w') as file14:
    json.dump(obj14.json(), file14, indent=2)

with open("./Test15.json", 'w') as file15:
    json.dump(obj15.json(), file15, indent=2)

with open("./Test16.json", 'w') as file16:
    json.dump(obj16.json(), file16, indent=2)

with open("./Test17.json", 'w') as file17:
    json.dump(obj17.json(), file17, indent=2)

with open("./Test18.json", 'w') as file18:
    json.dump(obj18.json(), file18, indent=2)

with open("./Test19.json", 'w') as file19:
    json.dump(obj19.json(), file19, indent=2)

with open("./Test20.json", 'w') as file20:
    json.dump(obj20.json(), file20, indent=2)
